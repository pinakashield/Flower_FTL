# %%
import pandas as pd

# Load the CSV file and randomly sample 50,000 rows
file_path = '/Users/peenalgupta/PinakaShield/GitHub/Flower_FTL_IDS/dataset/CICIDS_2017.csv'  # Replace with your CSV file path
df = pd.read_csv(file_path).sample(n=50000, random_state=42)

# Display the first few rows of the dataframe
df.head()
# Out:
# /var/folders/c4/684yzyz529g8v36q2knhbjxm0000gn/T/ipykernel_2399/336753707.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path).sample(n=50000, random_state=42)
#          Destination Port   Flow Duration   Total Fwd Packets  \
# 2075756             64105            13.0                 1.0
# 267934                 53         30774.0                 1.0
# 1507119             59996          1680.0                 3.0
# 361932               8083            44.0                 1.0
# 2153290                53           668.0                 1.0
#
#           Total Backward Packets  Total Length of Fwd Packets  \
# 2075756                      1.0                          0.0
# 267934                       1.0                         51.0
# 1507119                      0.0                         31.0
# 361932                       1.0                          2.0
# ...

# %%
output_file_path = 'output_file.csv'  # Replace with your desired output file path
df.to_csv(output_file_path, index=False)
